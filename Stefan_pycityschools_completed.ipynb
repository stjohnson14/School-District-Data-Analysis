# %%
import pandas as pd
import csv as csv
import numpy as np
from functools import reduce

# %%
school_data_load= 'Resources/schools_complete.csv'

# %%
student_data_load= 'Resources/students_complete.csv'

# %%
school_data = pd.read_csv(school_data_load)
student_data= pd.read_csv(student_data_load)

# %%
school_data_complete = pd.merge(student_data, school_data, on= 'school_name')

# %%
school_data_complete = school_data_complete.rename(columns={'school_name': 'School Name'})
school_data_complete
# Out:
#        Student ID       student_name gender grade         School Name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
total_schools= school_data_complete['School ID'].unique()

# %%
total_schools= len(total_schools)

# %%
total_schools
# Out:
# 15

# %%
total_students= school_data_complete['Student ID'].unique()
total_students= len(total_students)
total_students
# Out:
# 39170

# %%
no_duplicates_ID= school_data_complete.drop_duplicates(subset='School ID')
no_duplicates_ID
total_budget = no_duplicates_ID['budget'].sum()
total_budget
# Out:
# 24649428

# %%
average_math= school_data_complete['math_score'].mean()
average_math
# Out:
# 78.98537145774827

# %%
average_reading= school_data_complete['reading_score'].mean()
average_reading
# Out:
# 81.87784018381414

# %%
school_data_complete['math_score']= school_data_complete['math_score'].astype(float)
passing_math = school_data_complete.loc[school_data_complete["math_score"] >=70]
passing_math_percent = (len(passing_math)/total_students)*100
passing_math_percent


#passing_math_percent = (passing_math / total_students) * 100
# Out:
# 74.9808526933878

# %%
school_data_complete['reading_score']= school_data_complete['reading_score'].astype(float)
passing_read = school_data_complete.loc[school_data_complete["reading_score"] >=70]
passing_read_percent = (len(passing_read)/total_students)*100
passing_read_percent
# Out:
# 85.80546336482001

# %%
combined_passing = school_data_complete.loc[(school_data_complete['reading_score'] >=70) & (school_data_complete['math_score'] > 69)]
combined_passing_percent = (len(combined_passing)/total_students)*100
combined_passing_percent
# Out:
# 65.17232575950983

# %%
#create data frame to hold values

# %%
results = [{
    "Total Schools": total_schools,
    "Total Students": total_students,
    "Total Budget": total_budget,
    "Average Math Score": average_math, 
    "Average Reading Score": average_reading,
    "% Passing Math": passing_math_percent,
    "% Passing Reading": passing_read_percent,
    "% Overall Passing": combined_passing_percent}]

# %%
district_summary_df = pd.DataFrame(results)
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
no_duplicates_school= school_data_complete.drop_duplicates(subset='school_name')
#new_indexes = school_data_complete['school_name'].tolist()
new_index = no_duplicates_school['school_name'].tolist()
abc_index = sorted(new_index)

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
total_schools_name = school_data_complete.groupby('School Name')
type_df = total_schools_name['type'].unique()
type_df
# Out:
# School Name
# Bailey High School       [District]
# Cabrera High School       [Charter]
# Figueroa High School     [District]
# Ford High School         [District]
# Griffin High School       [Charter]
# Hernandez High School    [District]
# Holden High School        [Charter]
# Huang High School        [District]
# Johnson High School      [District]
# Pena High School          [Charter]
# Rodriguez High School    [District]
# Shelton High School       [Charter]
# Thomas High School        [Charter]
# Wilson High School        [Charter]
# Wright High School        [Charter]
# Name: type, dtype: object

# %%
total_students = school_data_complete.groupby(['School Name']).count()['student_name']
per_school_budget = school_data_complete.groupby(["School Name"]).mean()["budget"]
per_student_budget = per_school_budget / total_students
student_math_avg = school_data_complete.groupby(["School Name"]).mean()['math_score']
student_reading_avg = school_data_complete.groupby(["School Name"]).mean()['reading_score']
school_passing_math = school_data_complete[(school_data_complete["math_score"] >= 70)]
per_school_passing_math = school_passing_math.groupby(["School Name"]).count()["student_name"]
per_school_counts = school_data_complete.groupby(["School Name"]).count()["Student ID"]
per_school_passing_math = per_school_passing_math / per_school_counts * 100
school_passing_read = school_data_complete[(school_data_complete["reading_score"] >= 70)]
per_school_passing_read = school_passing_read.groupby(["School Name"]).count()["student_name"]
per_school_passing_read = per_school_passing_read / per_school_counts * 100

# %%
school_passing_overall = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)]
per_school_passing_overall = school_passing_overall.groupby(["School Name"]).count()["student_name"]
per_school_passing_overall = per_school_passing_overall / per_school_counts * 100
per_school_passing_overall
# Out:
# School Name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
# Convert dictionary into a DataFrame
school_results = {
    "School Type": type_df,
    "Total Students": total_students,
    "Total School Budget": per_school_budget,
     "Budget Per Student":per_student_budget,
      "Average Math Score": student_math_avg,
     "Average Reading Score": student_reading_avg,
     "% Passing Math": per_school_passing_math,
     "% Passing Reading": per_school_passing_read,
     "% Overall Passing": per_school_passing_overall
}

# Convert dictionary into DataFrame
school_results = pd.DataFrame({"School Type": type_df,
                               "Total Students": total_students,
                               "Total School Budget": per_school_budget,
                                "Budget Per Student" : per_student_budget,
                                "Average Math Score" : student_math_avg,
                                "Average Reading Score": student_reading_avg,
                                "% Passing Math": per_school_passing_math,
                                "% Passing Reading": per_school_passing_read,
                                "% Overall Passing": per_school_passing_overall
                              })

# Reformat to dollars
school_results["Total School Budget"] = school_results["Total School Budget"].map("${:,.0f}".format)
school_results["Budget Per Student"] = school_results["Budget Per Student"].map("${:,.0f}".format)
school_results["Average Math Score"] = school_results["Average Math Score"].map("{:.0f}".format)
school_results["Average Reading Score"] = school_results["Average Reading Score"].map("{:.0f}".format)
school_results["% Passing Math"] = school_results["% Passing Math"].map("{:.2f}%".format)
school_results["% Passing Reading"] = school_results["% Passing Reading"].map("{:.2f}%".format)
school_results["% Overall Passing"] = school_results["% Overall Passing"].map("{:.2f}%".format)

school_results
# Out:
#                       School Type  Total Students Total School Budget  \
# School Name
# Bailey High School     [District]            4976          $3,124,928
# Cabrera High School     [Charter]            1858          $1,081,356
# Figueroa High School   [District]            2949          $1,884,411
# Ford High School       [District]            2739          $1,763,916
# Griffin High School     [Charter]            1468            $917,500
# Hernandez High School  [District]            4635          $3,022,020
# Holden High School      [Charter]             427            $248,087
# Huang High School      [District]            2917          $1,910,635
# Johnson High School    [District]            4761          $3,094,650
# Pena High School        [Charter]             962            $585,858
# Rodriguez High School  [District]            3999          $2,547,363
# Shelton High School     [Charter]            1761          $1,056,600
# ...

# %%
top_overall_schools = school_results.sort_values(['% Overall Passing'], ascending=False)
top_overall_schools.head()
# Out:
#                     School Type  Total Students Total School Budget  \
# School Name
# Cabrera High School   [Charter]            1858          $1,081,356
# Thomas High School    [Charter]            1635          $1,043,130
# Griffin High School   [Charter]            1468            $917,500
# Wilson High School    [Charter]            2283          $1,319,574
# Pena High School      [Charter]             962            $585,858
#
#                     Budget Per Student Average Math Score  \
# School Name
# Cabrera High School               $582                 83
# Thomas High School                $638                 83
# Griffin High School               $625                 83
# Wilson High School                $578                 83
# Pena High School                  $609                 84
#
#                     Average Reading Score % Passing Math % Passing Reading  \
# School Name
# Cabrera High School                    84         94.13%            97.04%
# ...

# %%
bottom_overall_schools = school_results.sort_values(['% Overall Passing'])
bottom_overall_schools.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# School Name
# Rodriguez High School  [District]            3999          $2,547,363
# Figueroa High School   [District]            2949          $1,884,411
# Huang High School      [District]            2917          $1,910,635
# Hernandez High School  [District]            4635          $3,022,020
# Johnson High School    [District]            4761          $3,094,650
#
#                       Budget Per Student Average Math Score  \
# School Name
# Rodriguez High School               $637                 77
# Figueroa High School                $639                 77
# Huang High School                   $655                 77
# Hernandez High School               $652                 77
# Johnson High School                 $650                 77
#
#                       Average Reading Score % Passing Math % Passing Reading  \
# School Name
# ...

# %%
only_9_math = school_data_complete.loc[school_data_complete["grade"] == "9th"]
only_9_math = only_9_math.rename(columns={'math_score': '9th'})
only_10_math = school_data_complete.loc[school_data_complete["grade"] == "10th"]
only_10_math = only_10_math.rename(columns={'math_score': '10th'})
only_11_math = school_data_complete.loc[school_data_complete["grade"] == "11th"]
only_11_math = only_11_math.rename(columns={'math_score': '11th'})
only_12_math = school_data_complete.loc[school_data_complete["grade"] == "12th"]
only_12_math = only_12_math.rename(columns={'math_score': '12th'})

# %%
grouped_9 = only_9_math.groupby(["School Name"]).mean(['math_score'])
del grouped_9['reading_score']
del grouped_9['School ID']
del grouped_9['size']
del grouped_9['budget']
del grouped_9['Student ID']
grouped_10 = only_10_math.groupby(["School Name"]).mean(['math_score'])
del grouped_10['reading_score']
del grouped_10['School ID']
del grouped_10['size']
del grouped_10['budget']
del grouped_10['Student ID']
grouped_11 = only_11_math.groupby(["School Name"]).mean(['math_score'])
del grouped_11['reading_score']
del grouped_11['School ID']
del grouped_11['size']
del grouped_11['budget']
del grouped_11['Student ID']
grouped_12 = only_12_math.groupby(["School Name"]).mean(['math_score'])
del grouped_12['reading_score']
del grouped_12['School ID']
del grouped_12['size']
del grouped_12['budget']
del grouped_12['Student ID']

# %%
data_frames = [grouped_9, grouped_10, grouped_11, grouped_12]
math_by_grade = reduce(lambda  left,right: pd.merge(left,right,on=['School Name'],
                                            how='outer'), data_frames)
math_by_grade
# Out:
#                              9th       10th       11th       12th
# School Name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
only_9_read = school_data_complete.loc[school_data_complete["grade"] == "9th"]
only_9_read = only_9_read.rename(columns={'reading_score': '9th'})
only_10_read = school_data_complete.loc[school_data_complete["grade"] == "10th"]
only_10_read = only_10_read.rename(columns={'reading_score': '10th'})
only_11_read = school_data_complete.loc[school_data_complete["grade"] == "11th"]
only_11_read = only_11_read.rename(columns={'reading_score': '11th'})
only_12_read = school_data_complete.loc[school_data_complete["grade"] == "12th"]
only_12_read = only_12_read.rename(columns={'reading_score': '12th'})

# %%
grouped_9_read = only_9_read.groupby(["School Name"]).mean(['reading_score'])
del grouped_9_read['math_score']
del grouped_9_read['School ID']
del grouped_9_read['size']
del grouped_9_read['budget']
del grouped_9_read['Student ID']
grouped_10_read = only_10_read.groupby(["School Name"]).mean(['reading_score'])
del grouped_10_read['math_score']
del grouped_10_read['School ID']
del grouped_10_read['size']
del grouped_10_read['budget']
del grouped_10_read['Student ID']
grouped_11_read = only_11_read.groupby(["School Name"]).mean(['reading_score'])
del grouped_11_read['math_score']
del grouped_11_read['School ID']
del grouped_11_read['size']
del grouped_11_read['budget']
del grouped_11_read['Student ID']
grouped_12_read = only_12_read.groupby(["School Name"]).mean(['reading_score'])
del grouped_12_read['math_score']
del grouped_12_read['School ID']
del grouped_12_read['size']
del grouped_12_read['budget']
del grouped_12_read['Student ID']

# %%
data_frames = [grouped_9_read, grouped_10_read, grouped_11_read, grouped_12_read]
reading_by_grade = reduce(lambda  left,right: pd.merge(left,right,on=['School Name'],
                                            how='outer'), data_frames)
reading_by_grade
# Out:
#                              9th       10th       11th       12th
# School Name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
max(per_student_budget)
# Out:
# 655.0

# %%
spending_results = pd.DataFrame({
                                "Average Math Score" : student_math_avg,
                                "Average Reading Score": student_reading_avg,
                                "% Passing Math": per_school_passing_math,
                                "% Passing Reading": per_school_passing_read,
                                "% Overall Passing": per_school_passing_overall,
                                "Spending Ranges (Per Student)": per_student_budget
                              })

# %%
spending_results
# Out:
#                        Average Math Score  Average Reading Score  \
# School Name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
bins = [0, 585, 630, 645, 680]
group_names= ["$585", "$585-630", "$630-645", "$645-680"]

spending_results["Spending Ranges"] = pd.cut(spending_results["Spending Ranges (Per Student)"], bins, labels=group_names, include_lowest=True)

# %%
spending_results
# Out:
#                        Average Math Score  Average Reading Score  \
# School Name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
spending_results = spending_results.groupby("Spending Ranges")

# %%
spending_results.max()
# Out:
#                  Average Math Score  Average Reading Score  % Passing Math  \
# Spending Ranges
# $585                      83.803279              83.989488       94.133477
# $585-630                  83.839917              84.044699       94.594595
# $630-645                  83.418349              83.848930       93.272171
# $645-680                  77.289752              81.182722       66.752967
#
#                  % Passing Reading  % Overall Passing  \
# Spending Ranges
# $585                     97.039828          91.334769
# $585-630                 97.138965          90.599455
# $630-645                 97.308869          90.948012
# $645-680                 81.316421          53.539172
#
#                  Spending Ranges (Per Student)
# Spending Ranges
# $585                                     583.0
# $585-630                                 628.0
# $630-645                                 644.0
# $645-680                                 655.0

# %%
school_size_results2 = pd.DataFrame({
                                "Average Math Score" : student_math_avg,
                                "Average Reading Score": student_reading_avg,
                                "% Passing Math": per_school_passing_math,
                                "% Passing Reading": per_school_passing_read,
                                "% Overall Passing": per_school_passing_overall,
                                "Total Students": total_students
                              })

# %%
school_size_results2
# Out:
#                        Average Math Score  Average Reading Score  \
# School Name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
size_bins = [1, 1000, 2000, 5000]
size_bins_names = ["Small ( 1000)", "Medium (1000-2000)", "Large (2000-5000)"]

school_size_results2["Size Ranges"] = pd.cut(school_size_results2["Total Students"], size_bins, labels=size_bins_names, include_lowest=True)
school_size_results2
# Out:
#                        Average Math Score  Average Reading Score  \
# School Name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
school_size_results2 = school_size_results2.groupby(["Size Ranges"])
school_size_results2.max()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Size Ranges
# Small ( 1000)                83.839917              84.044699       94.594595
# Medium (1000-2000)           83.682222              83.975780       94.133477
# Large (2000-5000)            83.274201              83.989488       93.867718
#
#                     % Passing Reading  % Overall Passing  Total Students
# Size Ranges
# Small ( 1000)               96.252927          90.540541             962
# Medium (1000-2000)          97.308869          91.334769            1858
# Large (2000-5000)           96.539641          90.582567            4976

# %%
school_type_results1 = pd.DataFrame({
                                "Average Math Score" : student_math_avg,
                                "Average Reading Score": student_reading_avg,
                                "% Passing Math": per_school_passing_math,
                                "% Passing Reading": per_school_passing_read,
                                "% Overall Passing": per_school_passing_overall,
                                "Type": type_df })
school_type_results1
# Out:
#                        Average Math Score  Average Reading Score  \
# School Name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
bins = [0, 75, 100]
group_names = ['District', 'Charter']
school_type_results1['Type of School'] = pd.cut(school_type_results1['% Overall Passing'], bins, labels=group_names, include_lowest=True)

# %%
school_type_results1
# Out:
#                        Average Math Score  Average Reading Score  \
# School Name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
school_type_results1 = school_type_results1.groupby(["Type of School"])
school_type_results1.max()
# Out:
#                 Average Math Score  Average Reading Score  % Passing Math  \
# Type of School
# District                 77.289752              81.182722       68.309602
# Charter                  83.839917              84.044699       94.594595
#
#                 % Passing Reading  % Overall Passing      Type
# Type of School
# District                81.933280          54.642283  District
# Charter                 97.308869          91.334769   Charter
